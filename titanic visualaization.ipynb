# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=sns.load_dataset('titanic')
sns.pairplot(df,hue='sex')
# Out:
# C:\Users\student\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
fig.savefig('kavin.png')

# %%
mea=df['survived'].mean()
mea
# Out:
# 0.3838383838383838

# %%
mea2=df['age'].mean()
mea2
# Out:
# 29.69911764705882

# %%
sns.set_context('poster',font_scale=1)
fig=plt.figure(figsize=(30,15))

g=sns.boxplot(x='survived',y='age',data=df,hue='sex')

# %%
sns.displot(df['pclass'],,bins=10)

# %%
sns.kdeplot(df['pclass'])
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='Density'>

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.set_style('darkgrid')
fig=plt.figure(figsize=(30,15),dpi=500)
sns.set_context('poster',font_scale=1)
sns.violinplot(x='survived',y='pclass',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='pclass'>

# %%
df.groupby('deck').describe()
# Out:
#      survived                                               pclass            \
#         count      mean       std  min   25%  50%  75%  max  count      mean
# deck
# A        15.0  0.466667  0.516398  0.0  0.00  0.0  1.0  1.0   15.0  1.000000
# B        47.0  0.744681  0.440755  0.0  0.50  1.0  1.0  1.0   47.0  1.000000
# C        59.0  0.593220  0.495450  0.0  0.00  1.0  1.0  1.0   59.0  1.000000
# D        33.0  0.757576  0.435194  0.0  1.00  1.0  1.0  1.0   33.0  1.121212
# E        32.0  0.750000  0.439941  0.0  0.75  1.0  1.0  1.0   32.0  1.312500
# F        13.0  0.615385  0.506370  0.0  0.00  1.0  1.0  1.0   13.0  2.384615
# G         4.0  0.500000  0.577350  0.0  0.00  0.5  1.0  1.0    4.0  3.000000
#
#       ... parch       fare                                            \
#       ...   75%  max count        mean         std      min      25%
# deck  ...
# A     ...  0.00  2.0  15.0   39.623887   17.975333   0.0000  30.8479
# ...

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
